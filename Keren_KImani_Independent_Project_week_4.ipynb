# %% [markdown]
# <a href="https://colab.research.google.com/github/KerenKimani/FRIDAY-IPs/blob/master/Keren_KImani_Independent_Project_week_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np

# %%
aut = pd.read_csv('/content/Autolib_dataset (2).csv')
aut.tail()
# Out:
#                           Address  Cars  Bluecar counter  ...  day  hour  minute
# 4995          8 avenue M̩nelotte     2                2  ...    6    11      26
# 4996            37 rue de Dantzig     4                4  ...    4    16      56
# 4997               142 rue du Bac     1                1  ...    1     7       1
# 4998  2 avenue du Val de Fontenay     2                2  ...    4    17      27
# 4999          5 Rue Henry Brisson     4                4  ...    8    10       2
#
# [5 rows x 25 columns]

# %%
desc = pd.read_csv('/content/description.csv')
desc
# Out:
#             Column name  ...                                           Comments
# 0               Address  ...                             address of the station
# 1                  Cars  ...  Number of cars available at the station - redu...
# 2       Bluecar counter  ...        Number of Bluecars available at the station
# 3        Utilib counter  ...         Number of Utilibs available at the station
# 4    Utilib 1.4 counter  ...     Number of Utilib 1.4  available at the station
# 5          Charge Slots  ...  Number of Charging slots available at the station
# 6       Charging Status  ...  Whether the station is operational for recharg...
# 7                  City  ...                                               City
# 8     Displayed comment  ...  Some comments like "station within parking, ac...
# 9                    ID  ...                                  ID of the station
# 10                 Kind  ...  "CENTER" have no resources at all; "PARKING" d...
# ...

# %%
aut.isnull()
num_rows = aut.shape[0]
num_missing = num_rows - aut.count() 
num_missing
# Out:
# Address                   0
# Cars                      0
# Bluecar counter           0
# Utilib counter            0
# Utilib 1.4 counter        0
# Charge Slots              0
# Charging Status           0
# City                      0
# Displayed comment      4889
# ID                        0
# Kind                      0
# Geo point                 0
# Postal code               0
# Public name               0
# Rental status             0
# Scheduled at           4953
# Slots                     0
# Station type              0
# Status                    0
# Subscription status       0
# year                      0
# month                     0
# day                       0
# hour                      0
# minute                    0
# dtype: int64

# %%
aut = aut.drop(['Displayed comment','Scheduled at','Geo point' ], axis=1)
aut.head()
# Out:
#                               Address  Cars  Bluecar counter  ...  day  hour  minute
# 0                 2 Avenue de Suffren     0                0  ...    8    11      43
# 1           145 Rue Raymond Losserand     6                6  ...    6     7      24
# 2    2 Avenue John Fitzgerald Kennedy     3                3  ...    3    20      14
# 3              51 Rue Eug̬ne Oudin̩     3                3  ...    4     4      37
# 4  6 avenue de la Porte de Champerret     3                3  ...    8    17      23
#
# [5 rows x 22 columns]

# %%
aut.count()
# Out:
# Address                5000
# Cars                   5000
# Bluecar counter        5000
# Utilib counter         5000
# Utilib 1.4 counter     5000
# Charge Slots           5000
# Charging Status        5000
# City                   5000
# ID                     5000
# Kind                   5000
# Postal code            5000
# Public name            5000
# Rental status          5000
# Slots                  5000
# Station type           5000
# Status                 5000
# Subscription status    5000
# year                   5000
# month                  5000
# day                    5000
# hour                   5000
# minute                 5000
# dtype: int64

# %%
aut = aut.loc[(aut['Subscription status'] != 'future') &(aut['Status'] != 'scheduled')  & (aut['Kind'] != 'CENTRE')]
aut = aut[np.logical_or(aut['Rental status'] == 'operational', aut['Rental status'] == 'broken')]
aut
# Out:
#                                  Address  Cars  ...  hour  minute
# 0                    2 Avenue de Suffren     0  ...    11      43
# 1              145 Rue Raymond Losserand     6  ...     7      24
# 2       2 Avenue John Fitzgerald Kennedy     3  ...    20      14
# 3                 51 Rue Eug̬ne Oudin̩     3  ...     4      37
# 4     6 avenue de la Porte de Champerret     3  ...    17      23
# ...                                  ...   ...  ...   ...     ...
# 4995                 8 avenue M̩nelotte     2  ...    11      26
# 4996                   37 rue de Dantzig     4  ...    16      56
# 4997                      142 rue du Bac     1  ...     7       1
# 4998         2 avenue du Val de Fontenay     2  ...    17      27
# 4999                 5 Rue Henry Brisson     4  ...    10       2
#
# [4950 rows x 22 columns]

# %%
#char = aut.loc[(aut['Charging Status'] != 'operational')]
#char.loc[(char['Charge Slots']> 0)]

aut = aut[np.logical_or((aut['Charging Status']== 'operational') , (aut['Charge Slots'] > 0))]
aut
# Out:
#                                Address  Cars  ...  hour  minute
# 1            145 Rue Raymond Losserand     6  ...     7      24
# 2     2 Avenue John Fitzgerald Kennedy     3  ...    20      14
# 3               51 Rue Eug̬ne Oudin̩     3  ...     4      37
# 10                      14 rue Censier     0  ...     4      39
# 14          8 Boulevard Richard Lenoir     0  ...     8       0
# ...                                ...   ...  ...   ...     ...
# 4992                   3 avenue d'Ivry     0  ...    23       1
# 4994                  15 rue de Rocroy     0  ...    20      49
# 4996                 37 rue de Dantzig     4  ...    16      56
# 4997                    142 rue du Bac     1  ...     7       1
# 4999               5 Rue Henry Brisson     4  ...    10       2
#
# [1995 rows x 22 columns]

# %%
bluef = aut.loc[(aut['City'] == 'Paris') & (aut['Bluecar counter'] > 1 )]
bluef['hour'].value_counts()
# Out:
# 9     55
# 21    53
# 10    52
# 2     48
# 15    47
# 8     46
# 7     46
# 6     45
# 13    44
# 3     44
# 1     43
# 16    42
# 12    42
# 18    41
# 0     40
# 4     39
# 5     39
# 11    38
# 19    36
# 14    35
# 23    35
# 17    34
# 22    33
# 20    28
# Name: hour, dtype: int64

# %%
aut['hour'].value_counts()
# Out:
# 21    101
# 7      91
# 16     91
# 9      91
# 15     90
# 13     89
# 10     88
# 2      86
# 20     85
# 6      84
# 8      84
# 1      82
# 23     82
# 12     82
# 14     82
# 18     80
# 4      80
# 3      80
# 17     78
# 5      77
# 19     76
# 11     75
# 0      71
# 22     70
# Name: hour, dtype: int64

# %%
aut['ID'].value_counts()
# Out:
# paris-portedemontrouge-8      13
# paris-courcelles-69           11
# paris-philippeauguste-126     11
# paris-voltaire-182            11
# paris-rapee-46                10
#                               ..
# paris-peguy-2                  1
# paris-lecourbe-336             1
# paris-pastourelle-27           1
# paris-jeanveber-3              1
# paris-pierre1erdeserbie-33     1
# Name: ID, Length: 432, dtype: int64

# %%
auth = aut.loc[(aut['hour'] == 21)]
auth['ID'].value_counts()
# Out:
# paris-tronchet-19         4
# paris-voltaire-182        3
# paris-emilereynaud-4      2
# paris-danton-8            2
# paris-mozart-68           2
#                          ..
# paris-balard-108          1
# suresnes-marcelmonge-2    1
# paris-monge-58            1
# paris-victorhugo-93       1
# paris-marceau-59          1
# Name: ID, Length: 88, dtype: int64

# %%
post = aut.loc[(aut['Bluecar counter'] >1)]
post['Postal code'].value_counts()
# Out:
# 75017    110
# 75016    108
# 75020     93
# 75015     92
# 75013     78
# 75019     75
# 75011     73
# 75012     61
# 75014     60
# 75018     59
# 75010     38
# 75008     37
# 75007     32
# 75005     25
# 75009     18
# 92150     15
# 93700     13
# 93260     10
# 75006     10
# 75003      9
# 75002      9
# 75004      8
# 93350      7
# 92230      6
# 92330      6
# 93150      6
# 92130      5
# 91330      5
# 75116      5
# 92100      5
# 92390      5
# 92800      5
# 92400      4
# 92210      4
# 75001      4
# 92250      3
# 92220      3
# 93100      2
# 94160      2
# 75112      1
# Name: Postal code, dtype: int64

# %%
aut.loc[(aut['ID'] == 'paris-portedemontrouge-8')]
# Out:
#                                 Address  Cars  ...  hour  minute
# 122   8 Avenue de la Porte de Montrouge     3  ...    19      57
# 194   8 Avenue de la Porte de Montrouge     1  ...    16       5
# 360   8 Avenue de la Porte de Montrouge     0  ...    22      12
# 1010  8 Avenue de la Porte de Montrouge     5  ...     2      46
# 1282  8 Avenue de la Porte de Montrouge     4  ...    10      37
# 1527  8 Avenue de la Porte de Montrouge     3  ...    15       0
# 2112  8 Avenue de la Porte de Montrouge     5  ...    11      19
# 2179  8 Avenue de la Porte de Montrouge     1  ...    19      41
# 2991  8 Avenue de la Porte de Montrouge     0  ...    14       9
# 3307  8 Avenue de la Porte de Montrouge     3  ...    12      30
# 3392  8 Avenue de la Porte de Montrouge     3  ...    21       4
# 3558  8 Avenue de la Porte de Montrouge     5  ...     3      50
# 4490  8 Avenue de la Porte de Montrouge     6  ...     0      21
#
# [13 rows x 22 columns]

# %%
aut.loc[(aut['ID'] == 'paris-tronchet-19')]
# Out:
#               Address  Cars  Bluecar counter  ...  day  hour  minute
# 600   19 rue Tronchet     0                0  ...    6     4      20
# 1630  19 rue Tronchet     0                0  ...    5     3      10
# 2172  19 rue Tronchet     0                0  ...    4    21       9
# 2873  19 rue Tronchet     0                0  ...    9    21      26
# 2885  19 rue Tronchet     0                0  ...    4    21      28
# 3219  19 rue Tronchet     0                0  ...    8    21      20
# 4129  19 rue Tronchet     6                6  ...    7    12      22
#
# [7 rows x 22 columns]
